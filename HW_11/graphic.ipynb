# %%
from sympy import *
from sympy.plotting import plot
init_printing()

# %%
x = Symbol("x")
f = x**3 - 50*x 
f
# Out:
#  3
# x  - 50⋅x

# %%
g = x**4 + 88*x**2 - 241
g
# Out:
#  4       2
# x  + 88⋅x  - 241

# %%
h = f-g

# %%
plot(f,g)

# %%
plot(h)
